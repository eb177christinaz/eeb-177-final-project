# %% [markdown]
# # Lightning Talk for Chiroptera (Bats)

# %%
from IPython.core.display import Image
Image(filename=("/home/eeb177-student/Desktop/eeb-177/final-project/chiroptera/BatPhoto.jpg"))

# %% [markdown]
# #### Bats are one of the most successful mammals, with 1,300 currently alive.

# %% [markdown]
# #### Important pollinators, pest controlers, seed dispersers

# %%
from IPython.core.display import Image
Image(filename=("/home/eeb177-student/Desktop/eeb-177/final-project/chiroptera/GlobalSpeciesRichness.jpg"))

# %% [markdown]
# #### Image Credit: Bat Conservation International

# %% [markdown]
# #### Though bats are very successful, they don't fossilize well.

# %% [markdown]
# #### For example, of my 1200+ dataset, only around 150 had location data.

# %%
from IPython.core.display import Image
Image(filename=("/home/eeb177-student/Desktop/eeb-177/final-project/chiroptera/Batfossilmap.png"))

# %% [markdown]
# ### Since they are so successful, I wanted to look at fossil occurances over time

# %% [markdown]
# ### Function:

# %%
###this functions writes a new csv file that has the genus, species, min age, and maxage

infile = "/home/eeb177-student/Desktop/eeb-177/final-project/chiroptera/newchiropteradata.csv"
with open(infile,'r') as bat_records:
        trial = bat_records.readlines()[17:]



output = open("/home/eeb177-student/Desktop/eeb-177/final-project/chiroptera/newchiropteragenusspecies-age.csv", "w")

for line in trial:
        species = line.split('","')[5].strip('"') 
        min_age = line.split('","')[11].strip('"')
        max_age =  line.split('","')[10].strip('"')
        genus = species.split(" ")[0].strip('"')

        outline = "{},{},{},{}\n".format(genus,species,min_age,max_age)
        output.write(outline)
        print(outline)
# Out:
# Ageina,Ageina tobieni,50.3,55.8
#
# Honrovits,Honrovits tsuwape,50.3,55.8
#
# Microchiroptera,Microchiroptera,46.2,50.3
#
# Chiroptera,Chiroptera,46.2,50.3
#
# Ageina,Ageina,46.2,50.3
#
# Icaronycteris,Icaronycteris,46.2,50.3
#
# Microchiroptera,Microchiroptera,46.2,50.3
#
# Chiroptera,Chiroptera,40.4,46.2
#
# Wallia,Wallia scalopidens,40.4,46.2
#
# Chiroptera,Chiroptera,40.4,46.2
#
# Microchiroptera,Microchiroptera,40.4,46.2
#
# Chiroptera,Chiroptera,40.4,46.2
#
# Chiroptera,Chiroptera,40.4,46.2
#
# Chiroptera,Chiroptera,40.4,46.2
#
# Chiroptera,Chiroptera,40.4,46.2
#
# Chiroptera,Chiroptera,40.4,46.2
#
# Chiroptera,Chiroptera,40.4,46.2
#
# Chiroptera,Chiroptera,40.4,46.2
#
# Chiroptera,Chiroptera,37.2,40.4
#
# Wallia,Wallia scalopidens,37.2,40.4
#
# Vespertilionoidea,Vespertilionoidea,37.2,40.4
#
# Chiroptera,Chiroptera,33.9,37.2
#
# Chiroptera,Chiroptera,33.9,37.2
#
# Wallia,Wallia,33.9,37.2
#
# Chadronycteris,Chadronycteris rabenae,33.9,37.2
#
# Chiroptera,Chiroptera,33.9,37.2
#
# ...

# %%
from IPython.core.display import Image
Image(filename=("/home/eeb177-student/Desktop/eeb-177/final-project/chiroptera/BatOccurrences.png"))

# %% [markdown]
# ### We get a glimpse of how abundant bats are in terms of species richness

# %% [markdown]
# ### There is an increase in speciation events starting from about 20 million years ago, but what about now?

# %%
from IPython.core.display import Image
Image(filename=("/home/eeb177-student/Desktop/eeb-177/final-project/chiroptera/BatAssessment.png"))

# %%
from IPython.display import IFrame
IFrame("Chiropterapyrate.pdf", width=600, height=600)
# Out:
#         <iframe
#             width="600"
#             height="600"
#             src="Chiropterapyrate.pdf"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
from IPython.core.display import Image
Image(filename=("/home/eeb177-student/Desktop/eeb-177/final-project/chiroptera/babybats.jpg"))

# %% [markdown]
# # Link to github:
# ### https://github.com/eb177christinaz
